# %% [markdown]
# # Métodos numéricos
# ## Tarea 8
# **Nombre:** Luis Enrique Pérez Señalin

# %%
import numpy as np
import sympy as sp
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
import funciones

# %% [markdown]
# ### Ejercicio 1

# %%
# Leer los datos de 1.csv para el ejercicio 1
filename = './datos/1.csv'
df1 = pd.read_csv(filename)
x, y = df1['x'],df1['y']
x_pred = np.linspace(x.min(),x.max(),100)

# %%
#a
solution_grado2, my_function = funciones.grado2(x, y)
y_pred = my_function(x)
mse = mean_squared_error(y, y_pred)
print(f'{solution_grado2}, error: {mse}')
# Out:
# {b0: -191.572418526473, b1: 71.6102437202353}, error: 105.88388862638901

# %%
y_pred = my_function(x)
funciones.plot_points_line(x, y , x, y_pred)
del y_pred, my_function

# %%
#B
solution_grado3, my_function = funciones.grado3(x, y)
y_pred = my_function(x)
mse = mean_squared_error(y, y_pred)
print(f'{solution_grado3}, error:{mse}')
# Out:
# {a: 8.21707232027677, b: -19.3086037920577, c: 51.0007893901555}, error:55.16562001170247

# %%
y_pred = my_function(x_pred)
funciones.plot_points_line(x, y , x_pred, y_pred)
del y_pred, my_function

# %%
#C
solution_grado4, my_function = funciones.grado4(x, y)
y_pred = my_function(x)
mse = mean_squared_error(y, y_pred)
print(f'{solution_grado4}, error: {mse}')
# Out:
# {a: -2.60683872291530, b: 51.5609569358385, c: -254.874783382474, d: 469.163265281457}, error: 51.838306474030546

# %%
y_pred = my_function(x_pred)
funciones.plot_points_line(x, y , x_pred, y_pred)
del y_pred, my_function

# %%
#D
solution_d, my_function = funciones.resolver_d(x, y)
y_pred = my_function(x)
mse = mean_squared_error(y, y_pred)
print(f"{solution_d} error: {mse}")
# Out:
# {'a': 0.3684766238316912, 'b': 24.776723697838264} error: 82.10051092575841

# %%
y_pred = my_function(x_pred)
funciones.plot_points_line(x, y, x_pred,y_pred)
del my_function, y_pred

# %%
#E
solution_e, my_function = funciones.resolver_e(x, y)
y_pred = my_function(x)
mse = mean_squared_error(y, y_pred)
print(f"{solution_e} error: {mse}")
# Out:
# {'a': 1.993284578947818, 'b': 6.518682345786362} error: 58.15572726014282

# %%
y_pred = my_function(x_pred)
funciones.plot_points_line(x, y, x_pred,y_pred)
del my_function, y_pred

# %%
del x, y, x_pred, df1

# %% [markdown]
# ### Ejercicio 2

# %%
# Leer los datos de 2.csv para el ejercicio 2
filename = './datos/2.csv'
df2 = pd.read_csv(filename)
x, y = df2['x'],df2['y']
x_pred = np.linspace(x.min(),x.max(),100)

# %%
#a
solution_grado2, my_function = funciones.grado2(x, y)
y_pred = my_function(x)
mse = mean_squared_error(y, y_pred)
print(f"{solution_grado2} error: {mse}")
# Out:
# {b0: -0.512456824000000, b1: 1.66554008000000} error: 0.04194873196993601

# %%
y_pred = my_function(x)
funciones.plot_points_line(x, y , x, y_pred)
del y_pred, my_function

# %%
#B
solution_grado3, my_function = funciones.grado3(x, y)
y_pred = my_function(x)
mse = mean_squared_error(y, y_pred)
print(f"{solution_grado3} error: {mse}")
# Out:
# {a: 1.12942386701952, b: -0.311403456830963, c: 0.0851439325173668} error: 0.00030248936617833984

# %%
y_pred = my_function(x_pred)
funciones.plot_points_line(x, y , x_pred, y_pred)
del y_pred, my_function

# %%
#C
solution_grado4, my_function = funciones.grado4(x, y)
y_pred = my_function(x)
mse = mean_squared_error(y, y_pred)
print(f"{solution_grado4} error: {mse}")
# Out:
# {a: 0.266208097739524, b: 0.402932213097654, c: 0.248385784190561, d: -0.0184013992962260} error: 6.343339444534826e-07

# %%
y_pred = my_function(x_pred)
funciones.plot_points_line(x, y , x_pred, y_pred)
del y_pred, my_function

# %%
#D
solution_d, my_function = funciones.resolver_d(x, y)
y_pred = my_function(x)
mse = mean_squared_error(y, y_pred)
print(f"{solution_d} error: {mse}")
# Out:
# {'a': 2.707294686913415, 'b': 0.045707480695330406} error: 0.13438106289864651

# %%
y_pred = my_function(x_pred)
funciones.plot_points_line(x, y , x_pred, y_pred)
del y_pred, my_function

# %%
#E
solution_e, my_function = funciones.resolver_e(x, y)
y_pred = my_function(x)
mse = mean_squared_error(y, y_pred)
print(f"{solution_e} error: {mse}")
# Out:
# {'a': 1.872009284326524, 'b': 0.9501564755920636} error: 0.006809597528292772

# %%
y_pred = my_function(x_pred)
funciones.plot_points_line(x, y, x_pred,y_pred)
del my_function, y_pred

# %%
del x, y, x_pred, df2

# %% [markdown]
# ### Ejercicio 3

# %%
# Leer los datos de 4.csv para el ejercicio 4
filename = './datos/3.csv'
df = pd.read_csv(filename)
df = df.sort_values(by = 'Puntuación ACT')
x = df['Puntuación ACT']
y = df['Promedio de puntos']
x_pred = np.linspace(x.min(),x.max(),100)

# %%
#Ordernar los valores de Puntuación.
funciones.plot_points(x, y)

# %%
solution, lineal_function = funciones.grado2(x, y)
print(f'b0 y b1:{solution}')
# Out:
# b0 y b1:{b0: 0.486575663026521, b1: 0.100858034321373}

# %%
y_pred = lineal_function(x_pred)
# Set the grid to plot the values
funciones.plot_points_line(x, y, x_pred, y_pred)
y_pred = lineal_function(x)
mse = mean_squared_error(y, y_pred)
print(f"Error: {mse}")
# Out:
# Error: 0.25243528081123245

# %% [markdown]
# ### Ejercicio 4

# %%
# Leer los datos de 4.csv para el ejercicio 4
filename = './datos/4.csv'
df = pd.read_csv(filename)
df = df.sort_values(by = 'Peso promedio')
x = df['Peso promedio']
y = df['Porcentaje de presentación']
x_pred = np.linspace(x.min(),x.max(),100)

# %%
#Ordernar los valores de Puntuación.
funciones.plot_points(x, y)

# %%
solution, lineal_function = funciones.grado2(x, y)
print(f'b0 y b1:{solution}')
# Out:
# b0 y b1:{b0: 13.1464995678479, b1: -0.00225496974935177}

# %%
y_pred = lineal_function(x_pred)
# Set the grid to plot the values
funciones.plot_points_line(x, y, x_pred, y_pred)
y_pred = lineal_function(x)
mse = mean_squared_error(y, y_pred)
print(f"Error: {mse}")
# Out:
# Error: 0.41182713915298164
